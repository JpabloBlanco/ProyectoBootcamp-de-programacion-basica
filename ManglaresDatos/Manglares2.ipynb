# %%
import pandas as pd
import plotly.express as px
import dash
import dash_core_components as dcc
import dash_html_components as html
# Out:
# C:\Users\talento\AppData\Local\Temp\ipykernel_8472\221038820.py:4: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\Users\talento\AppData\Local\Temp\ipykernel_8472\221038820.py:5: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
df=pd.read_excel("C:\\Datos\\regalias_2019.xlsx",sheet_name="regalias_2019")
df

# %%
df.info()

# %%
df1=df[df["DescripciÃ³n del proyecto"].str.contains("MANGL")]
df1

# %%
df2=df[df["Departamento"]=="BOLÃVAR"]
df2

# %%
#Hay solamente tres en los cuales se habla de manglar (en las descripciones de los proyectos)

# %%
df_2=pd.read_csv("C:\\Users\\talento\\Downloads\\ProyectoBootcamp-de-programacion-basica-master\\Maquetación\\ManglaresDatos\\432e-zwh4.csv")
df_2

# %%
df3=df_2[df_2["objeto_del_contrato"].str.contains("MANGLAR")]
df3

# %%
df4=df3["descripcion_del_proceso"]
df4

# %%
df_2.at[21,"descripcion_del_proceso"]

# %%
#Lo que pasó aquí es que en las descripciones de los procesos se hicieron prestaciones a la entidad Parque Espíritu del manglar

# %%
df_3=pd.read_csv("C:\\Users\\talento\\Downloads\\ProyectoBootcamp-de-programacion-basica-master\\Maquetación\\ManglaresDatos\\xikz-44ja.csv")
df_3

# %%
#df5=df_3[df_3["codigomunicipio"].str.contains("Caribe")]
df5=df_3[df_3["codigomunicipio"]==70221]
df5

# %%
df_3.at[317,"nombreproyecto"]

# %%
df_4=pd.read_csv("C:\\Users\\talento\\Downloads\\ProyectoBootcamp-de-programacion-basica-master\\Maquetación\\ManglaresDatos\\2t8c-queb.csv")
df_4

# %%
df6=df_4[df_4["nombre_proyecto"].str.contains("MANGL")]
df6

# %%
df_5=pd.read_csv("C:\\Users\\talento\\Downloads\\ProyectoBootcamp-de-programacion-basica-master\\Maquetación\\ManglaresDatos\\Contratos_de_Acceso_a_Recursos_Gen_ticos_-_Listado_Minambiente.csv")
df_5
# Out:
#      EXPEDIENTE                                NOMBRE DEL PROYECTO   \
# 0    RGE 0152-08  Producción de alcoholes empleando cepas nativa...
# 1       RGE 0060  Estudio de la bioprospección de las esponjas m...
# 2    RGE 0152-06  Bioprospección de Microorganismos Marinos de C...
# 3    RGE 0152-07  Bioprospección de invertebrados marinos y alga...
# 4           2788  Caracterización genética delfín sudamericano S...
# ..           ...                                                ...
# 617     RGE 0461  Estudio químico y de actividad biológica de di...
# 618     RGE 0462  Diseño y evaluación de inóculos a nivel de lab...
# 619     RGE 0463  Uso de la biodiversidad colombiana, a través d...
# 620     RGE 0464  Bioprospección de fitocompuestos con actividad...
# 621     RGE 0465  Evaluación de la nanocelulosa bacteriana como ...
#
#                             SOLICITANTE N° AUTO DE INICIO   \
# 0      Universidad Nacional de Colombia                NaN
# ...

# %%
df7=df_5[df_5["NOMBRE DEL PROYECTO"].str.contains("mangl")]
df7
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df7=df_5[df_5["SOLICITANTE"].str.contains("Sabana")]
#       2 df7
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4092, in DataFrame.__getitem__(self, key)
#    4089     return self.where(key)
#    4091 # Do we have a (boolean) 1d indexer?
# -> 4092 if com.is_bool_indexer(key):
#    4093     return self._getitem_bool_array(key)
#    4095 # We are left with two options: a single key, and a collection of keys,
#    4096 # We interpret tuples as collections only for non-MultiIndex
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\common.py:136, in is_bool_indexer(key)
#     132     na_msg = "Cannot mask with non-boolean array containing NA / NaN values"
#     133     if lib.is_bool_array(key_array, skipna=True):
# ...

# %%
#Con esta fuente de datos no sé cuál ha sido el problema. El archivo es reconocido y el dataframe es generado,
#pero no  parece que reconozca apropiadamente la categoría.
