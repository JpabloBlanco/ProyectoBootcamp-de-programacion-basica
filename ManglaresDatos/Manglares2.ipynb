# %%
import pandas as pd
import plotly.express as px
import dash
import dash_core_components as dcc
import dash_html_components as html
# Out:
# C:\Users\talento\AppData\Local\Temp\ipykernel_5964\221038820.py:4: UserWarning:
# The dash_core_components package is deprecated. Please replace
# `import dash_core_components as dcc` with `from dash import dcc`
#   import dash_core_components as dcc
# C:\Users\talento\AppData\Local\Temp\ipykernel_5964\221038820.py:5: UserWarning:
# The dash_html_components package is deprecated. Please replace
# `import dash_html_components as html` with `from dash import html`
#   import dash_html_components as html

# %%
df=pd.read_excel("C:\\Datos\\regalias_2019.xlsx",sheet_name="regalias_2019")
df
# Out:
#                     Nombre OCAD      Tipo OCAD     RegiÃ³n Departamento  \
# 0      OCAD - COMISIÃ“N RECTORA       REGIONAL  CENTRO SUR     PUTUMAYO
# 1      OCAD - COMISIÃ“N RECTORA       REGIONAL   DEL LLANO       ARAUCA
# 2      OCAD - COMISIÃ“N RECTORA       REGIONAL  CENTRO SUR     CAQUETÃ
# 3      OCAD - COMISIÃ“N RECTORA       REGIONAL  CENTRO SUR     PUTUMAYO
# 4      OCAD - COMISIÃ“N RECTORA       REGIONAL   DEL LLANO       ARAUCA
# ...                         ...            ...         ...          ...
# 14871    DEPARTAMENTO DE TOLIMA  DEPARTAMENTAL  CENTRO SUR       TOLIMA
# 14872        CESAR - SAN MARTIN      MUNICIPAL      CARIBE        CESAR
# 14873    CÃ“RDOBA - LA APARTADA      MUNICIPAL      CARIBE     CÃ“RDOBA
# 14874    LA GUAJIRA - HATONUEVO      MUNICIPAL      CARIBE   LA GUAJIRA
# 14875        CESAR - SAN MARTIN      MUNICIPAL      CARIBE        CESAR
#
#        CÃ³digo DANE ente ejecutor          Entidad ejecutora Tipo de ejecutor  \
# 0                           86000  DEPARTAMENTO DEL PUTUMAYO     DEPARTAMENTO
# 1                           81000    DEPARTAMENTO DEL ARAUCA     DEPARTAMENTO
# 2                           18000   DEPARTAMENTO DEL CAQUETA     DEPARTAMENTO
# 3                           86000  DEPARTAMENTO DEL PUTUMAYO     DEPARTAMENTO
# 4                           81000    DEPARTAMENTO DEL ARAUCA     DEPARTAMENTO
# ...                           ...                        ...              ...
# 14871                       73000    DEPARTAMENTO DEL TOLIMA     DEPARTAMENTO
# 14872                       20770    MUNICIPIO DE SAN MARTIN        MUNICIPIO
# 14873                       23350   MUNICIPIO DE LA APARTADA        MUNICIPIO
# 14874                       44378     MUNICIPIO DE HATONUEVO        MUNICIPIO
# 14875                       20770    MUNICIPIO DE SAN MARTIN        MUNICIPIO
#
#                                Sector  \
# 0                          EDUCACIÃ“N
# 1      AGRICULTURA Y DESARROLLO RURAL
# 2                          EDUCACIÃ“N
# 3                          EDUCACIÃ“N
# 4      AGRICULTURA Y DESARROLLO RURAL
# ...                               ...
# 14871                INFLEXIBILIDADES
# 14872                INFLEXIBILIDADES
# 14873                INFLEXIBILIDADES
# 14874                INFLEXIBILIDADES
# 14875                INFLEXIBILIDADES
#
#                                                Subsector           BPin  ...  \
# 0              EducaciÃ³n - Preescolar y BÃ¡sica y Media  2012000010001  ...
# 1      Agricultura - AdquisiciÃ³n y AdjudicaciÃ³n de ...  2012000010002  ...
# 2              EducaciÃ³n - Preescolar y BÃ¡sica y Media  2012000010003  ...
# 3              EducaciÃ³n - Preescolar y BÃ¡sica y Media  2012000010004  ...
# 4      Agricultura - AdquisiciÃ³n y AdjudicaciÃ³n de ...  2012000010005  ...
# ...                                                  ...            ...  ...
# 14871                                    Inflexibiidades     INFLEX1299  ...
# 14872                                    Inflexibiidades     INFLEX1305  ...
# 14873                                    Inflexibiidades     INFLEX1304  ...
# 14874                                    Inflexibiidades     INFLEX1303  ...
# 14875                                    Inflexibiidades     INFLEX1306  ...
#
#       Fuentes SGR FCTEI  Fuentes SGR Cormagdalena  \
# 0                   NaN                       NaN
# 1                   NaN                       NaN
# 2                   NaN                       NaN
# 3                   NaN                       NaN
# 4                   NaN                       NaN
# ...                 ...                       ...
# 14871               NaN                       NaN
# 14872               NaN                       NaN
# 14873               NaN                       NaN
# 14874               NaN                       NaN
# 14875               NaN                       NaN
#
#        Fuentes SGR incentivo a la producciÃ³n  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# ...                                       ...
# 14871                                     NaN
# 14872                                     NaN
# 14873                                     NaN
# 14874                                     NaN
# 14875                                     NaN
#
#       Fuentes SGR asignaciÃ³n para la paz AP50  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 14871                                      NaN
# 14872                                      NaN
# 14873                                      NaN
# 14874                                      NaN
# 14875                                      NaN
#
#       Fuentes SGR asignaciÃ³n para la paz APFDR50  Fuentes SGR FONPET  \
# 0                                             NaN                 NaN
# 1                                             NaN                 NaN
# 2                                             NaN                 NaN
# 3                                             NaN                 NaN
# 4                                             NaN                 NaN
# ...                                           ...                 ...
# 14871                                         NaN                 NaN
# 14872                                         NaN                 NaN
# 14873                                         NaN                 NaN
# 14874                                         NaN                 NaN
# 14875                                         NaN                 NaN
#
#        Valor total SGR  Valor total naciÃ³n  Valor total otros  \
# 0           3031000000                  NaN                NaN
# 1           4498835000                  NaN                NaN
# 2           4228760000                  NaN                NaN
# 3             80020000                  NaN                NaN
# 4           8879500000                  NaN                NaN
# ...                ...                  ...                ...
# 14871        538135825                  NaN                NaN
# 14872       1239535118                  NaN                NaN
# 14873        616296465                  NaN                NaN
# 14874        582794777                  NaN                NaN
# 14875       1441985822                  NaN                NaN
#
#        Valor total proyectos
# 0                 3031000000
# 1                 4498835000
# 2                 4228760000
# 3                   80020000
# 4                 8879500000
# ...                      ...
# 14871              538135800
# 14872             1239535000
# 14873              616296500
# 14874              582794800
# 14875             1441986000
#
# [14876 rows x 29 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14876 entries, 0 to 14875
# Data columns (total 29 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Nombre OCAD                                  14876 non-null  object
#  1   Tipo OCAD                                    14876 non-null  object
#  2   RegiÃ³n                                      14876 non-null  object
#  3   Departamento                                 14876 non-null  object
#  4   CÃ³digo DANE ente ejecutor                   14876 non-null  int64
#  5   Entidad ejecutora                            14876 non-null  object
#  6   Tipo de ejecutor                             14876 non-null  object
#  7   Sector                                       14876 non-null  object
#  8   Subsector                                    14876 non-null  object
#  9   BPin                                         14876 non-null  object
#  10  DescripciÃ³n del proyecto                    14876 non-null  object
#  11  Avance fÃ­sico                               14876 non-null  float64
#  12  Avance financiero                            14876 non-null  float64
#  13  Estado                                       14876 non-null  object
#  14  Fecha de aprobaciÃ³n                         14876 non-null  datetime64[ns]
#  15  Fuentes SGR directas                         6632 non-null   float64
#  16  Fuentes SGR FCR 40                           7543 non-null   float64
#  17  Fuentes SGR FCR 40.1                         1020 non-null   float64
#  18  Fuentes SGR FDR                              784 non-null    float64
#  19  Fuentes SGR FCTEI                            360 non-null    float64
#  20  Fuentes SGR Cormagdalena                     43 non-null     float64
#  21  Fuentes SGR incentivo a la producciÃ³n       287 non-null    float64
#  22  Fuentes SGR asignaciÃ³n para la paz AP50     155 non-null    float64
#  23  Fuentes SGR asignaciÃ³n para la paz APFDR50  40 non-null     float64
#  24  Fuentes SGR FONPET                           10 non-null     float64
#  25  Valor total SGR                              14876 non-null  int64
#  26  Valor total naciÃ³n                          301 non-null    float64
#  27  Valor total otros                            3659 non-null   float64
#  28  Valor total proyectos                        14876 non-null  int64
# dtypes: datetime64[ns](1), float64(14), int64(3), object(11)
# memory usage: 3.3+ MB

# %%
df1=df[df["DescripciÃ³n del proyecto"].str.contains("MANGL")]
df1
# Out:
#                                              Nombre OCAD  \
# 1499   Departamento Administrativo de la Ciencia, la ...
# 6406                                  SUCRE - SAN ONOFRE
# 13947                                ANTIOQUIA - GIRALDO
#
#                    Tipo OCAD       RegiÃ³n Departamento  \
# 1499   CIENCIA Y TECNOLOGÃA  EJE CAFETERO    ANTIOQUIA
# 6406               MUNICIPAL        CARIBE        SUCRE
# 13947              MUNICIPAL  EJE CAFETERO    ANTIOQUIA
#
#        CÃ³digo DANE ente ejecutor          Entidad ejecutora Tipo de ejecutor  \
# 1499                         5000  DEPARTAMENTO DE ANTIOQUIA     DEPARTAMENTO
# 6406                        70713    MUNICIPIO DE SAN ONOFRE        MUNICIPIO
# 13947                        5306       MUNICIPIO DE GIRALDO        MUNICIPIO
#
#                                    Sector  \
# 1499   CIENCIA, TECNOLOGÃA E INNOVACIÃ“N
# 6406     AMBIENTE Y DESARROLLO SOSTENIBLE
# 13947               DEPORTE Y RECREACIÃ“N
#
#                                                Subsector           BPin  ...  \
# 1499   Ciencia y TecnologÃ­a - InvestigaciÃ³n y Desar...  2013000100173  ...
# 6406   Medio Ambiente y Riesgo Â - ConservaciÃ³n y us...  2014707130005  ...
# 13947              Deporte Â - Infraestructura deportiva  2018053060001  ...
#
#       Fuentes SGR FCTEI  Fuentes SGR Cormagdalena  \
# 1499        378843327.0                       NaN
# 6406                NaN                       NaN
# 13947               NaN                       NaN
#
#        Fuentes SGR incentivo a la producciÃ³n  \
# 1499                                      NaN
# 6406                                      NaN
# 13947                                     NaN
#
#       Fuentes SGR asignaciÃ³n para la paz AP50  \
# 1499                                       NaN
# 6406                                       NaN
# 13947                                      NaN
#
#       Fuentes SGR asignaciÃ³n para la paz APFDR50  Fuentes SGR FONPET  \
# 1499                                          NaN                 NaN
# 6406                                          NaN                 NaN
# 13947                                         NaN                 NaN
#
#        Valor total SGR  Valor total naciÃ³n  Valor total otros  \
# 1499         378843327                  NaN        211233312.0
# 6406        1900000000                  NaN                NaN
# 13947        114026512                  NaN          3000000.0
#
#        Valor total proyectos
# 1499               590076600
# 6406              1900000000
# 13947              117026500
#
# [3 rows x 29 columns]

# %%
df2=df[df["Departamento"]=="BOLÃVAR"]
df2
# Out:
#                    Nombre OCAD      Tipo OCAD RegiÃ³n Departamento  \
# 5               RegiÃ³n Caribe       REGIONAL  CARIBE     BOLÃVAR
# 11              RegiÃ³n Caribe       REGIONAL  CARIBE     BOLÃVAR
# 13              RegiÃ³n Caribe       REGIONAL  CARIBE     BOLÃVAR
# 14              RegiÃ³n Caribe       REGIONAL  CARIBE     BOLÃVAR
# 15              RegiÃ³n Caribe       REGIONAL  CARIBE     BOLÃVAR
# ...                        ...            ...     ...          ...
# 14354     BOLIVAR - SANTA ROSA      MUNICIPAL  CARIBE     BOLÃVAR
# 14355     BOLIVAR - VILLANUEVA      MUNICIPAL  CARIBE     BOLÃVAR
# 14578  DEPARTAMENTO DE BOLIVAR  DEPARTAMENTAL  CARIBE     BOLÃVAR
# 14702         BOLIVAR - CICUCO      MUNICIPAL  CARIBE     BOLÃVAR
# 14804  DEPARTAMENTO DE BOLIVAR  DEPARTAMENTAL  CARIBE     BOLÃVAR
#
#        CÃ³digo DANE ente ejecutor  \
# 5                           13000
# 11                          13000
# 13                          13000
# 14                          13000
# 15                          13000
# ...                           ...
# 14354                       13683
# 14355                       13873
# 14578                       13000
# 14702                       13188
# 14804                       13000
#
#                                      Entidad ejecutora Tipo de ejecutor  \
# 5                              DEPARTAMENTO DE BOLIVAR     DEPARTAMENTO
# 11                             DEPARTAMENTO DE BOLIVAR     DEPARTAMENTO
# 13                             DEPARTAMENTO DE BOLIVAR     DEPARTAMENTO
# 14                             DEPARTAMENTO DE BOLIVAR     DEPARTAMENTO
# 15                             DEPARTAMENTO DE BOLIVAR     DEPARTAMENTO
# ...                                                ...              ...
# 14354                          MUNICIPIO DE SANTA ROSA        MUNICIPIO
# 14355  MUNICIPIO DE VILLANUEVA DEPARTAMENTO DE BOLIVAR        MUNICIPIO
# 14578                          DEPARTAMENTO DE BOLIVAR     DEPARTAMENTO
# 14702                              MUNICIPIO DE CICUCO        MUNICIPIO
# 14804                          DEPARTAMENTO DE BOLIVAR     DEPARTAMENTO
#
#                                     Sector  \
# 5      INCLUSIÃ“N SOCIAL Y RECONCILIACIÃ“N
# 11       AGUA POTABLE Y SANEAMIENTO BASICO
# 13          AGRICULTURA Y DESARROLLO RURAL
# 14          AGRICULTURA Y DESARROLLO RURAL
# 15          AGRICULTURA Y DESARROLLO RURAL
# ...                                    ...
# 14354                           TRANSPORTE
# 14355                DEPORTE Y RECREACIÃ“N
# 14578                     INFLEXIBILIDADES
# 14702                     INFLEXIBILIDADES
# 14804                     INFLEXIBILIDADES
#
#                                                Subsector           BPin  ...  \
# 5      Desarrollo Social - Familia, primera infancia,...  2012000020001  ...
# 11     AGUA POTABLE Y SANEAMIENTO BASICO - Acueducto ...  2012000020008  ...
# 13           Agricultura - Proyectos de Desarrollo Rural  2012000020010  ...
# 14           Agricultura - Proyectos de Desarrollo Rural  2012000020011  ...
# 15           Agricultura - Proyectos de Desarrollo Rural  2012000020013  ...
# ...                                                  ...            ...  ...
# 14354  Transporte - Red urbana Â Â Â Â Â Â Â Â Â Â Â ...  2018136830001  ...
# 14355              Deporte Â - Infraestructura deportiva  2018138730012  ...
# 14578                                    Inflexibiidades     INFLEX1016  ...
# 14702                                    Inflexibiidades     INFLEX1143  ...
# 14804                                    Inflexibiidades     INFLEX1247  ...
#
#       Fuentes SGR FCTEI  Fuentes SGR Cormagdalena  \
# 5                   NaN                       NaN
# 11                  NaN                       NaN
# 13                  NaN                       NaN
# 14                  NaN                       NaN
# 15                  NaN                       NaN
# ...                 ...                       ...
# 14354               NaN                       NaN
# 14355               NaN                       NaN
# 14578               NaN                       NaN
# 14702               NaN                       NaN
# 14804               NaN                       NaN
#
#        Fuentes SGR incentivo a la producciÃ³n  \
# 5                                         NaN
# 11                                        NaN
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# ...                                       ...
# 14354                                     NaN
# 14355                                     NaN
# 14578                                     NaN
# 14702                                     NaN
# 14804                                     NaN
#
#       Fuentes SGR asignaciÃ³n para la paz AP50  \
# 5                                          NaN
# 11                                         NaN
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# ...                                        ...
# 14354                                      NaN
# 14355                                      NaN
# 14578                                      NaN
# 14702                                      NaN
# 14804                                      NaN
#
#       Fuentes SGR asignaciÃ³n para la paz APFDR50  Fuentes SGR FONPET  \
# 5                                             NaN                 NaN
# 11                                            NaN                 NaN
# 13                                            NaN                 NaN
# 14                                            NaN                 NaN
# 15                                            NaN                 NaN
# ...                                           ...                 ...
# 14354                                         NaN                 NaN
# 14355                                         NaN                 NaN
# 14578                                         NaN                 NaN
# 14702                                         NaN                 NaN
# 14804                                         NaN                 NaN
#
#        Valor total SGR  Valor total naciÃ³n  Valor total otros  \
# 5            885953012                  NaN                NaN
# 11          5438119212                  NaN                NaN
# 13          3000000000                  NaN        621890000.0
# 14          2999998190                  NaN                NaN
# 15          1000000000                  NaN        127200000.0
# ...                ...                  ...                ...
# 14354        937020678                  NaN                NaN
# 14355       1142610997                  NaN                NaN
# 14578      10858000000                  NaN                NaN
# 14702        128748199                  NaN                NaN
# 14804       5429000000                  NaN                NaN
#
#        Valor total proyectos
# 5                  885953000
# 11                5438119000
# 13                3621890000
# 14                2999998000
# 15                1127200000
# ...                      ...
# 14354              937020700
# 14355             1142611000
# 14578            10858000000
# 14702              128748200
# 14804             5429000000
#
# [596 rows x 29 columns]

# %%
#Hay solamente tres en los cuales se habla de manglar (en las descripciones de los proyectos)

# %%
df_2=pd.read_csv("C:\\Users\\talento\\Downloads\\ProyectoBootcamp-de-programacion-basica-master\\Maquetación\\ManglaresDatos\\432e-zwh4.csv")
df_2
# Out:
#                                         nombre_entidad  nit_entidad  \
# 0    ALCALDÍA DEL DISTRITO TURÍSTICO Y CULTURAL DE ...    890480184
# 1    ALCALDÍA DEL DISTRITO TURÍSTICO Y CULTURAL DE ...    890480184
# 2    ALCALDÍA DEL DISTRITO TURÍSTICO Y CULTURAL DE ...    890480184
# 3    ALCALDÍA DEL DISTRITO TURÍSTICO Y CULTURAL DE ...    890480184
# 4    ALCALDÍA DEL DISTRITO TURÍSTICO Y CULTURAL DE ...    890480184
# ..                                                 ...          ...
# 995  ALCALDÍA DEL DISTRITO TURÍSTICO Y CULTURAL DE ...    890480184
# 996  ALCALDÍA DEL DISTRITO TURÍSTICO Y CULTURAL DE ...    890480184
# 997  ALCALDÍA DEL DISTRITO TURÍSTICO Y CULTURAL DE ...    890480184
# 998  ALCALDÍA DEL DISTRITO TURÍSTICO Y CULTURAL DE ...    890480184
# 999  INSTITUTO DE PATRIMONIO Y CULTURAL DE CARTAGEN...    806013631
#
#     departamento     ciudad                     localizaci_n        orden  \
# 0        Bolívar  Cartagena  Colombia,  Bolívar ,  Cartagena  Territorial
# 1        Bolívar  Cartagena  Colombia,  Bolívar ,  Cartagena  Territorial
# 2        Bolívar  Cartagena  Colombia,  Bolívar ,  Cartagena  Territorial
# 3        Bolívar  Cartagena  Colombia,  Bolívar ,  Cartagena  Territorial
# 4        Bolívar  Cartagena  Colombia,  Bolívar ,  Cartagena  Territorial
# ..           ...        ...                              ...          ...
# 995      Bolívar  Cartagena  Colombia,  Bolívar ,  Cartagena  Territorial
# 996      Bolívar  Cartagena  Colombia,  Bolívar ,  Cartagena  Territorial
# 997      Bolívar  Cartagena  Colombia,  Bolívar ,  Cartagena  Territorial
# 998      Bolívar  Cartagena  Colombia,  Bolívar ,  Cartagena  Territorial
# 999      Bolívar  Cartagena  Colombia,  Bolívar ,  Cartagena  Territorial
#
#                      sector       rama entidad_centralizada proceso_de_compra  \
# 0    No aplica/No pertenece  Ejecutivo         Centralizada  CO1.BDOS.6748013
# 1    No aplica/No pertenece  Ejecutivo         Centralizada  CO1.BDOS.6832269
# 2    No aplica/No pertenece  Ejecutivo         Centralizada  CO1.BDOS.3436806
# 3    No aplica/No pertenece  Ejecutivo         Centralizada  CO1.BDOS.6922686
# 4    No aplica/No pertenece  Ejecutivo         Centralizada  CO1.BDOS.1480603
# ..                      ...        ...                  ...               ...
# 995  No aplica/No pertenece  Ejecutivo         Centralizada  CO1.BDOS.2092112
# 996  No aplica/No pertenece  Ejecutivo         Centralizada  CO1.BDOS.5677087
# 997  No aplica/No pertenece  Ejecutivo         Centralizada  CO1.BDOS.2713656
# 998  No aplica/No pertenece  Ejecutivo         Centralizada  CO1.BDOS.3806873
# 999                 Cultura  Ejecutivo         Centralizada  CO1.BDOS.5520908
#
#      ... sistema_general_de_regal_as  \
# 0    ...                           0
# 1    ...                           0
# 2    ...                           0
# 3    ...                           0
# 4    ...                           0
# ..   ...                         ...
# 995  ...                           0
# 996  ...                           0
# 997  ...                           0
# 998  ...                           0
# 999  ...                           0
#
#     recursos_propios_alcald_as_gobernaciones_y_resguardos_ind_genas_  \
# 0                                              9750000
# 1                                              5533333
# 2                                              3400000
# 3                                             12000000
# 4                                              5400000
# ..                                                 ...
# 995                                           11200000
# 996                                           17500000
# 997                                           28000000
# 998                                           13600000
# 999                                           27000000
#
#     recursos_de_credito recursos_propios     ultima_actualizacion  \
# 0                     0                0                      NaN
# 1                     0                0  2024-12-18T00:00:00.000
# 2                     0                0                      NaN
# 3                     0                0                      NaN
# 4                     0                0  2020-12-16T00:00:00.000
# ..                  ...              ...                      ...
# 995                   0                0  2023-09-25T00:00:00.000
# 996                   0                0  2024-07-19T00:00:00.000
# 997                   0                0                      NaN
# 998                   0                0                      NaN
# 999                   0                0                      NaN
#
#     codigo_entidad fecha_inicio_liquidacion codigo_proveedor  \
# 0        703301051                      NaN        710328261
# 1        703301051                      NaN        720628635
# 2        703301051                      NaN        710775032
# 3        703301051                      NaN        726252844
# 4        703301051                      NaN        711088146
# ..             ...                      ...              ...
# 995      703301051                      NaN        710163668
# 996      703301051                      NaN        725348635
# 997      703301051                      NaN        716775309
# 998      703301051                      NaN        706158748
# 999      702775123                      NaN        706011053
#
#                                    objeto_del_contrato fecha_fin_liquidacion
# 0    PRESTACIÓN DE SERVICIOS DE APOYO A LA GESTIÓN ...                   NaN
# 1    PRESTAR SERVICIOS DE APOYO A LA GESTIÓN PARA B...                   NaN
# 2    PRESTACION DE SERVICIOS DE APOYO A LA GESTION ...                   NaN
# 3    PRESTACIÓN DE SERVICIOS PROFESIONALES EN EL MA...                   NaN
# 4    PRESTACIÓN DE SERVICIOS DE APOYO A LA GESTIÓN;...                   NaN
# ..                                                 ...                   ...
# 995  PRESTACIÓN DE SERVICIOS DE APOYO A LA GESTIÓN ...                   NaN
# 996  PRESTACIÓN DE SERVICIOS DE APOYO A LA GESTIÓN ...                   NaN
# 997  PRESTACIÓN DE SERVICIOS PROFESIONALES COMO ASE...                   NaN
# 998  PRESTACIÓN DE SERVICIOS DE APOYO A LA GESTION ...                   NaN
# 999  PRESTAR SERVICIOS PROFESIONALES COMO ARQUITECT...                   NaN
#
# [1000 rows x 71 columns]

# %%
df3=df_2[df_2["objeto_del_contrato"].str.contains("MANGLAR")]
df3
# Out:
#                                         nombre_entidad  nit_entidad  \
# 21   ALCALDÍA DEL DISTRITO TURÍSTICO Y CULTURAL DE ...    890480184
# 152  ALCALDÍA DEL DISTRITO TURÍSTICO Y CULTURAL DE ...    890480184
# 588  ALCALDÍA DEL DISTRITO TURÍSTICO Y CULTURAL DE ...    890480184
# 721  ALCALDÍA DEL DISTRITO TURÍSTICO Y CULTURAL DE ...    890480184
#
#     departamento     ciudad                     localizaci_n        orden  \
# 21       Bolívar  Cartagena  Colombia,  Bolívar ,  Cartagena  Territorial
# 152      Bolívar  Cartagena  Colombia,  Bolívar ,  Cartagena  Territorial
# 588      Bolívar  Cartagena  Colombia,  Bolívar ,  Cartagena  Territorial
# 721      Bolívar  Cartagena  Colombia,  Bolívar ,  Cartagena  Territorial
#
#                      sector       rama entidad_centralizada proceso_de_compra  \
# 21   No aplica/No pertenece  Ejecutivo         Centralizada  CO1.BDOS.7381286
# 152  No aplica/No pertenece  Ejecutivo         Centralizada  CO1.BDOS.7305535
# 588  No aplica/No pertenece  Ejecutivo         Centralizada  CO1.BDOS.7379465
# 721  No aplica/No pertenece  Ejecutivo         Centralizada  CO1.BDOS.7303977
#
#      ... sistema_general_de_regal_as  \
# 21   ...                           0
# 152  ...                           0
# 588  ...                           0
# 721  ...                           0
#
#     recursos_propios_alcald_as_gobernaciones_y_resguardos_ind_genas_  \
# 21                                            28000000
# 152                                           20000000
# 588                                           40000000
# 721                                           21600000
#
#     recursos_de_credito recursos_propios ultima_actualizacion codigo_entidad  \
# 21                    0                0                  NaN      703301051
# 152                   0                0                  NaN      703301051
# 588                   0                0                  NaN      703301051
# 721                   0                0                  NaN      703301051
#
#     fecha_inicio_liquidacion codigo_proveedor  \
# 21                       NaN        727668485
# 152                      NaN        727660706
# 588                      NaN        724650742
# 721                      NaN        727688509
#
#                                    objeto_del_contrato fecha_fin_liquidacion
# 21   PRESTACIÓN DE SERVICIOS PROFESIONALES DENTRO D...                   NaN
# 152  PRESTACIÓN DE SERVICIOS DE APOYO A LA GESTIÓN ...                   NaN
# 588  PRESTACIÓN DE SERVICIOS PROFESIONALES DENTRO D...                   NaN
# 721  PRESTACIÓN DE SERVICIOS DE APOYO A LA GESTIÓN ...                   NaN
#
# [4 rows x 71 columns]

# %%
df4=df3["descripcion_del_proceso"]
df4
# Out:
# 21     PRESTACIÓN DE SERVICIOS PROFESIONALES DENTRO D...
# 152    PRESTACIÓN DE SERVICIOS DE APOYO A LA GESTIÓN ...
# 588    PRESTACIÓN DE SERVICIOS PROFESIONALES DENTRO D...
# 721    PRESTACIÓN DE SERVICIOS DE APOYO A LA GESTIÓN ...
# Name: descripcion_del_proceso, dtype: object

# %%
df_2.at[21,"descripcion_del_proceso"]
# Out:
# 'PRESTACIÓN DE SERVICIOS PROFESIONALES DENTRO DEL PROYECTO DE INVERSION  REPARACIÓN MANTENIMIENTO Y DOTACIÓN DEL PARQUE ESPÍRITU DEL MANGLAR Y PARQUE DEL CENTENARIO DEL DISTRITO CARTAGENA DE INDIAS.'

# %%
#Lo que pasó aquí es que en las descripciones de los procesos se hicieron prestaciones a la entidad Parque Espíritu del manglar

# %%
df_3=pd.read_csv("C:\\Users\\talento\\Downloads\\ProyectoBootcamp-de-programacion-basica-master\\Maquetación\\ManglaresDatos\\xikz-44ja.csv")
df_3
# Out:
#                 bpin                                     nombreproyecto  \
# 0      2021761090012  Apoyo Para El Acceso A Estudiantes Becados Par...
# 1      2019057900024  Fortalecimiento Del Parque Automotor Y Maquina...
# 2     20251301010083  Optimización De Los Sistemas De Acueducto Y Al...
# 3    202500000001167  Fortalecimiento A La Comunidad Con Acceso A Se...
# 4      2012174460001  Mantenimiento De Las Vias Terciarias Del Munic...
# ..               ...                                                ...
# 995    2020050360006  Fortalecimiento  Del Proceso Gestión Jurídica ...
# 996    2017003760031  Asistencia Tcnica Para El Aumento Del Acceso A...
# 997    2022702330017  Construcción De Soluciones Sanitarias Para Onc...
# 998    2020175130037  Adquisición Regalos Para Ser Dados A Niñas Y N...
# 999    2021158220044  Mantenimiento De La Infraestructura Educativa ...
#
#        region  codigodepartamento        departamento  codigomunicipio  \
# 0    Pacífico                  76     Valle del Cauca            76109
# 1      Andina                   5           Antioquia             5790
# 2      Andina                  54  Norte de Santander            54800
# 3      Andina                  68           Santander            68211
# 4      Andina                  17              Caldas            17446
# ..        ...                 ...                 ...              ...
# 995    Andina                   5           Antioquia             5036
# 996  Pacífico                  76     Valle del Cauca            76000
# 997    Caribe                  70               Sucre            70233
# 998    Andina                  17              Caldas            17513
# 999    Andina                  15              Boyacá            15822
#
#          municipio           entidadresponsable  \
# 0     Buenaventura  BuenaventuraValle del Cauca
# 1           Tarazá              TarazáAntioquia
# 2          Teorama    TeoramaNorte de Santander
# 3     Contratación        ContrataciónSantander
# 4        Marulanda              MarulandaCaldas
# ..             ...                          ...
# 995    Angelópolis         AngelópolisAntioquia
# 996  Todo el Depto              Valle del Cauca
# 997       El Roble                El RobleSucre
# 998         Pácora                 PácoraCaldas
# 999           Tota                   TotaBoyacá
#
#                                 sector  idregion  codigoentidadresponsable
# 0                            Educación         6                   76109.0
# 1                           Transporte         2                    5790.0
# 2        Vivienda, Ciudad Y Territorio         2                   54800.0
# 3                      Minas Y Energía         2                   68211.0
# 4                           Transporte         2                   17446.0
# ..                                 ...       ...                       ...
# 995             Justicia Y Del Derecho         2                    5036.0
# 996  Inclusión Social Y Reconciliación         6                      76.0
# 997      Vivienda, Ciudad Y Territorio         3                   70233.0
# 998  Inclusión Social Y Reconciliación         2                   17513.0
# 999                          Educación         2                   15822.0
#
# [1000 rows x 11 columns]

# %%
#df5=df_3[df_3["codigomunicipio"].str.contains("Caribe")]
df5=df_3[df_3["codigomunicipio"]==70221]
df5
# Out:
#               bpin                                     nombreproyecto  region  \
# 317  2021702210028  Fortalecimiento De La Cultura Étnica (Població...  Caribe
#
#      codigodepartamento departamento  codigomunicipio municipio  \
# 317                  70        Sucre            70221   Coveñas
#
#     entidadresponsable                             sector  idregion  \
# 317       CoveñasSucre  Inclusión Social Y Reconciliación         3
#
#      codigoentidadresponsable
# 317                   70221.0

# %%
df_3.at[317,"nombreproyecto"]
# Out:
# 'Fortalecimiento De La Cultura Étnica (Población Afro E Indígena) A Través De Acciones Que Afiancen Y Mantengan Sus Tradiciones Valores Y Prácticas Culturales En El Municipio De  Coveñas Sucre'
